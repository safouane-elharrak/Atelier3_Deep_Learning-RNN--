# %% [markdown]
# # Character-level recurrent sequence-to-sequence model

# %% [markdown]
# ## Introduction

# %% [markdown]
# #### This example demonstrates how to implement a basic character-level recurrent sequence-to-sequence model. We apply it to translating short English sentences into short French sentences, character-by-character. Note that it is fairly unusual to do character-level machine translation, as word-level models are more common in this domain.
# ---

# %% [markdown]
# ## Setup

# %% [markdown]
# ### import all the libraries that we need

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# ## Download the data

# %%
# !!curl -O http://www.manythings.org/anki/fra-eng.zip
# !!unzip fra-eng.zip
# Out:
# ['Archive:  fra-eng.zip',
#  '  inflating: _about.txt              ',
#  '  inflating: fra.txt                 ']

# %% [markdown]
# ## Configuration

# %%
batch_size = 64  # Batch size for training.
epochs = 100  # Number of epochs to train for.
latent_dim = 256  # Latent dimensionality of the encoding space.
num_samples = 10000  # Number of samples to train on.
# Path to the data txt file on disk.
data_path = "fra.txt"

# %% [markdown]
# ## Prepare the data

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open(data_path, "r", encoding="utf-8") as f:
    lines = f.read().split("\n")
for line in lines[: min(num_samples, len(lines) - 1)]:
    input_text, target_text, _ = line.split("\t")
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = "\t" + target_text + "\n"
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

print("Number of samples:", len(input_texts))
print("Number of unique input tokens:", num_encoder_tokens)
print("Number of unique output tokens:", num_decoder_tokens)
print("Max sequence length for inputs:", max_encoder_seq_length)
print("Max sequence length for outputs:", max_decoder_seq_length)

input_token_index = dict([(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict([(char, i) for i, char in enumerate(target_characters)])

encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens), dtype="float32"
)
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)

for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.0
    encoder_input_data[i, t + 1 :, input_token_index[" "]] = 1.0
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.0
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.0
    decoder_input_data[i, t + 1 :, target_token_index[" "]] = 1.0
    decoder_target_data[i, t:, target_token_index[" "]] = 1.0
# Out:
# Number of samples: 10000
# Number of unique input tokens: 71
# Number of unique output tokens: 93
# Max sequence length for inputs: 15
# Max sequence length for outputs: 59

# %% [markdown]
# ## Build the model

# %%
# Define an input sequence and process it.
encoder_inputs = keras.Input(shape=(None, num_encoder_tokens))
encoder = keras.layers.LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)

# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = keras.Input(shape=(None, num_decoder_tokens))

# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = keras.layers.LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = keras.layers.Dense(num_decoder_tokens, activation="softmax")
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = keras.Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %% [markdown]
# ## Train the model

# %%
model.compile(
    optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"]
)
model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=0.2,
)
# Save model
model.save("s2s")
# Out:
# Epoch 1/100
# 125/125 [==============================] - 10s 22ms/step - loss: 1.1356 - accuracy: 0.7365 - val_loss: 1.0244 - val_accuracy: 0.7191
# Epoch 2/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.8142 - accuracy: 0.7801 - val_loss: 0.8401 - val_accuracy: 0.7682
# Epoch 3/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.6566 - accuracy: 0.8172 - val_loss: 0.7150 - val_accuracy: 0.7899
# Epoch 4/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.5700 - accuracy: 0.8352 - val_loss: 0.6303 - val_accuracy: 0.8166
# Epoch 5/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.5216 - accuracy: 0.8477 - val_loss: 0.5802 - val_accuracy: 0.8309
# Epoch 6/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.4855 - accuracy: 0.8568 - val_loss: 0.5545 - val_accuracy: 0.8373
# Epoch 7/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.4578 - accuracy: 0.8645 - val_loss: 0.5294 - val_accuracy: 0.8447
# Epoch 8/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.4350 - accuracy: 0.8705 - val_loss: 0.5146 - val_accuracy: 0.8478
# Epoch 9/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.4153 - accuracy: 0.8756 - val_loss: 0.4971 - val_accuracy: 0.8531
# Epoch 10/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3963 - accuracy: 0.8811 - val_loss: 0.4910 - val_accuracy: 0.8559
# Epoch 11/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3793 - accuracy: 0.8857 - val_loss: 0.4791 - val_accuracy: 0.8588
# Epoch 12/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3640 - accuracy: 0.8901 - val_loss: 0.4680 - val_accuracy: 0.8630
# Epoch 13/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3496 - accuracy: 0.8945 - val_loss: 0.4628 - val_accuracy: 0.8636
# Epoch 14/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.3357 - accuracy: 0.8987 - val_loss: 0.4581 - val_accuracy: 0.8656
# Epoch 15/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3226 - accuracy: 0.9023 - val_loss: 0.4476 - val_accuracy: 0.8691
# Epoch 16/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3104 - accuracy: 0.9063 - val_loss: 0.4505 - val_accuracy: 0.8689
# Epoch 17/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2986 - accuracy: 0.9099 - val_loss: 0.4419 - val_accuracy: 0.8724
# Epoch 18/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.2878 - accuracy: 0.9133 - val_loss: 0.4449 - val_accuracy: 0.8722
# Epoch 19/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.2770 - accuracy: 0.9166 - val_loss: 0.4394 - val_accuracy: 0.8741
# Epoch 20/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2675 - accuracy: 0.9193 - val_loss: 0.4379 - val_accuracy: 0.8741
# Epoch 21/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2579 - accuracy: 0.9218 - val_loss: 0.4413 - val_accuracy: 0.8747
# Epoch 22/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2490 - accuracy: 0.9247 - val_loss: 0.4378 - val_accuracy: 0.8758
# Epoch 23/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2406 - accuracy: 0.9271 - val_loss: 0.4394 - val_accuracy: 0.8765
# Epoch 24/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2323 - accuracy: 0.9295 - val_loss: 0.4428 - val_accuracy: 0.8765
# Epoch 25/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.2242 - accuracy: 0.9322 - val_loss: 0.4453 - val_accuracy: 0.8765
# Epoch 26/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2166 - accuracy: 0.9340 - val_loss: 0.4465 - val_accuracy: 0.8779
# Epoch 27/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2097 - accuracy: 0.9362 - val_loss: 0.4512 - val_accuracy: 0.8773
# Epoch 28/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2026 - accuracy: 0.9385 - val_loss: 0.4484 - val_accuracy: 0.8779
# Epoch 29/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1957 - accuracy: 0.9403 - val_loss: 0.4559 - val_accuracy: 0.8775
# Epoch 30/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1897 - accuracy: 0.9421 - val_loss: 0.4578 - val_accuracy: 0.8783
# Epoch 31/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1835 - accuracy: 0.9441 - val_loss: 0.4625 - val_accuracy: 0.8778
# Epoch 32/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1780 - accuracy: 0.9456 - val_loss: 0.4695 - val_accuracy: 0.8782
# Epoch 33/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1722 - accuracy: 0.9473 - val_loss: 0.4732 - val_accuracy: 0.8771
# Epoch 34/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1671 - accuracy: 0.9488 - val_loss: 0.4737 - val_accuracy: 0.8782
# Epoch 35/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1621 - accuracy: 0.9504 - val_loss: 0.4823 - val_accuracy: 0.8769
# Epoch 36/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1572 - accuracy: 0.9518 - val_loss: 0.4839 - val_accuracy: 0.8776
# Epoch 37/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.1526 - accuracy: 0.9533 - val_loss: 0.4883 - val_accuracy: 0.8776
# Epoch 38/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1481 - accuracy: 0.9543 - val_loss: 0.4912 - val_accuracy: 0.8770
# Epoch 39/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1439 - accuracy: 0.9556 - val_loss: 0.4959 - val_accuracy: 0.8779
# Epoch 40/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1396 - accuracy: 0.9568 - val_loss: 0.5050 - val_accuracy: 0.8770
# Epoch 41/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1360 - accuracy: 0.9581 - val_loss: 0.5037 - val_accuracy: 0.8771
# Epoch 42/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1323 - accuracy: 0.9593 - val_loss: 0.5083 - val_accuracy: 0.8779
# Epoch 43/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1285 - accuracy: 0.9603 - val_loss: 0.5161 - val_accuracy: 0.8766
# Epoch 44/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1252 - accuracy: 0.9610 - val_loss: 0.5257 - val_accuracy: 0.8768
# Epoch 45/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1216 - accuracy: 0.9622 - val_loss: 0.5306 - val_accuracy: 0.8765
# Epoch 46/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1182 - accuracy: 0.9633 - val_loss: 0.5353 - val_accuracy: 0.8770
# Epoch 47/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1157 - accuracy: 0.9638 - val_loss: 0.5337 - val_accuracy: 0.8772
# Epoch 48/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1127 - accuracy: 0.9646 - val_loss: 0.5425 - val_accuracy: 0.8772
# Epoch 49/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1100 - accuracy: 0.9655 - val_loss: 0.5449 - val_accuracy: 0.8768
# Epoch 50/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1074 - accuracy: 0.9662 - val_loss: 0.5494 - val_accuracy: 0.8764
# Epoch 51/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1047 - accuracy: 0.9671 - val_loss: 0.5603 - val_accuracy: 0.8762
# Epoch 52/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1020 - accuracy: 0.9678 - val_loss: 0.5641 - val_accuracy: 0.8759
# Epoch 53/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0996 - accuracy: 0.9686 - val_loss: 0.5703 - val_accuracy: 0.8755
# Epoch 54/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0974 - accuracy: 0.9692 - val_loss: 0.5752 - val_accuracy: 0.8747
# Epoch 55/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0953 - accuracy: 0.9697 - val_loss: 0.5768 - val_accuracy: 0.8755
# Epoch 56/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0928 - accuracy: 0.9702 - val_loss: 0.5782 - val_accuracy: 0.8764
# Epoch 57/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0911 - accuracy: 0.9711 - val_loss: 0.5833 - val_accuracy: 0.8751
# Epoch 58/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0890 - accuracy: 0.9716 - val_loss: 0.5951 - val_accuracy: 0.8760
# Epoch 59/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0875 - accuracy: 0.9719 - val_loss: 0.5969 - val_accuracy: 0.8755
# Epoch 60/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0851 - accuracy: 0.9727 - val_loss: 0.6030 - val_accuracy: 0.8755
# Epoch 61/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0835 - accuracy: 0.9730 - val_loss: 0.6046 - val_accuracy: 0.8751
# Epoch 62/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0817 - accuracy: 0.9736 - val_loss: 0.6073 - val_accuracy: 0.8766
# Epoch 63/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0801 - accuracy: 0.9741 - val_loss: 0.6112 - val_accuracy: 0.8750
# Epoch 64/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0781 - accuracy: 0.9746 - val_loss: 0.6239 - val_accuracy: 0.8748
# Epoch 65/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0769 - accuracy: 0.9749 - val_loss: 0.6322 - val_accuracy: 0.8737
# Epoch 66/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0753 - accuracy: 0.9757 - val_loss: 0.6221 - val_accuracy: 0.8750
# Epoch 67/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0736 - accuracy: 0.9761 - val_loss: 0.6359 - val_accuracy: 0.8733
# Epoch 68/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0723 - accuracy: 0.9765 - val_loss: 0.6319 - val_accuracy: 0.8744
# Epoch 69/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0712 - accuracy: 0.9767 - val_loss: 0.6370 - val_accuracy: 0.8746
# Epoch 70/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0695 - accuracy: 0.9770 - val_loss: 0.6408 - val_accuracy: 0.8744
# Epoch 71/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0683 - accuracy: 0.9774 - val_loss: 0.6498 - val_accuracy: 0.8735
# Epoch 72/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0669 - accuracy: 0.9778 - val_loss: 0.6556 - val_accuracy: 0.8739
# Epoch 73/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0658 - accuracy: 0.9780 - val_loss: 0.6623 - val_accuracy: 0.8738
# Epoch 74/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0646 - accuracy: 0.9783 - val_loss: 0.6595 - val_accuracy: 0.8737
# Epoch 75/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0637 - accuracy: 0.9787 - val_loss: 0.6605 - val_accuracy: 0.8734
# Epoch 76/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0625 - accuracy: 0.9792 - val_loss: 0.6688 - val_accuracy: 0.8735
# Epoch 77/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0614 - accuracy: 0.9793 - val_loss: 0.6691 - val_accuracy: 0.8732
# Epoch 78/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0603 - accuracy: 0.9797 - val_loss: 0.6812 - val_accuracy: 0.8727
# Epoch 79/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.0595 - accuracy: 0.9798 - val_loss: 0.6731 - val_accuracy: 0.8737
# Epoch 80/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.0584 - accuracy: 0.9801 - val_loss: 0.6815 - val_accuracy: 0.8735
# Epoch 81/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0576 - accuracy: 0.9803 - val_loss: 0.6882 - val_accuracy: 0.8729
# Epoch 82/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0565 - accuracy: 0.9808 - val_loss: 0.6979 - val_accuracy: 0.8729
# Epoch 83/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0558 - accuracy: 0.9809 - val_loss: 0.6948 - val_accuracy: 0.8732
# Epoch 84/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0549 - accuracy: 0.9809 - val_loss: 0.7021 - val_accuracy: 0.8728
# Epoch 85/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0543 - accuracy: 0.9813 - val_loss: 0.7045 - val_accuracy: 0.8731
# Epoch 86/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0534 - accuracy: 0.9816 - val_loss: 0.7050 - val_accuracy: 0.8734
# Epoch 87/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0525 - accuracy: 0.9819 - val_loss: 0.7090 - val_accuracy: 0.8728
# Epoch 88/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0516 - accuracy: 0.9820 - val_loss: 0.7078 - val_accuracy: 0.8739
# Epoch 89/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0509 - accuracy: 0.9821 - val_loss: 0.7131 - val_accuracy: 0.8733
# Epoch 90/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0502 - accuracy: 0.9823 - val_loss: 0.7185 - val_accuracy: 0.8723
# Epoch 91/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0495 - accuracy: 0.9827 - val_loss: 0.7187 - val_accuracy: 0.8735
# Epoch 92/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0488 - accuracy: 0.9830 - val_loss: 0.7262 - val_accuracy: 0.8728
# Epoch 93/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0484 - accuracy: 0.9830 - val_loss: 0.7251 - val_accuracy: 0.8737
# Epoch 94/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0479 - accuracy: 0.9831 - val_loss: 0.7295 - val_accuracy: 0.8729
# Epoch 95/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0471 - accuracy: 0.9833 - val_loss: 0.7367 - val_accuracy: 0.8726
# Epoch 96/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0466 - accuracy: 0.9832 - val_loss: 0.7364 - val_accuracy: 0.8724
# Epoch 97/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0464 - accuracy: 0.9836 - val_loss: 0.7385 - val_accuracy: 0.8726
# Epoch 98/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0456 - accuracy: 0.9837 - val_loss: 0.7381 - val_accuracy: 0.8730
# Epoch 99/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0451 - accuracy: 0.9837 - val_loss: 0.7448 - val_accuracy: 0.8724
# Epoch 100/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0442 - accuracy: 0.9841 - val_loss: 0.7476 - val_accuracy: 0.8723
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.

# %% [markdown]
# ## Run inference (sampling)
#   1-encode input and retrieve initial decoder state
#   2-run one step of decoder with this initial state and a "start of sequence"
#   token as target. Output will be the next target token.
#   3-Repeat with the current target token and current states

# %%
# Define sampling models
# Restore the model and construct the encoder and decoder.
model = keras.models.load_model("s2s")

encoder_inputs = model.input[0]  # input_1
encoder_outputs, state_h_enc, state_c_enc = model.layers[2].output  # lstm_1
encoder_states = [state_h_enc, state_c_enc]
encoder_model = keras.Model(encoder_inputs, encoder_states)

decoder_inputs = model.input[1]  # input_2
decoder_state_input_h = keras.Input(shape=(latent_dim,))
decoder_state_input_c = keras.Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_lstm = model.layers[3]
decoder_outputs, state_h_dec, state_c_dec = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs
)
decoder_states = [state_h_dec, state_c_dec]
decoder_dense = model.layers[4]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = keras.Model(
    [decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states
)

# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict((i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict((i, char) for char, i in target_token_index.items())


def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index["\t"]] = 1.0

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ""
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if sampled_char == "\n" or len(decoded_sentence) > max_decoder_seq_length:
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.0

        # Update states
        states_value = [h, c]
    return decoded_sentence

# %% [markdown]
# #### You can now generate decoded sentences as such:

# %%
for seq_index in range(20):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index : seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print("-")
    print("Input sentence:", input_texts[seq_index])
    print("Decoded sentence:", decoded_sentence)
# Out:
# 1/1 [==============================] - 0s 361ms/step
# 1/1 [==============================] - 0s 339ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# -
# Input sentence: Go.
# Decoded sentence: Marche.
#
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# -
# Input sentence: Go.
# Decoded sentence: Marche.
#
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# -
# Input sentence: Go.
# Decoded sentence: Marche.
#
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# -
# Input sentence: Go.
# Decoded sentence: Marche.
#
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# -
# Input sentence: Hi.
# Decoded sentence: Salut.
#
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# -
# Input sentence: Hi.
# Decoded sentence: Salut.
#
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# -
# Input sentence: Run!
# Decoded sentence: Fuyez !
#
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# -
# Input sentence: Run!
# Decoded sentence: Fuyez !
#
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# -
# Input sentence: Run!
# Decoded sentence: Fuyez !
#
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# -
# Input sentence: Run!
# Decoded sentence: Fuyez !
#
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# -
# Input sentence: Run!
# Decoded sentence: Fuyez !
#
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# -
# Input sentence: Run!
# Decoded sentence: Fuyez !
#
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# -
# Input sentence: Run!
# Decoded sentence: Fuyez !
#
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# -
# Input sentence: Run!
# Decoded sentence: Fuyez !
#
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# -
# Input sentence: Run.
# Decoded sentence: Fuyez !
#
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# -
# Input sentence: Run.
# Decoded sentence: Fuyez !
#
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# -
# Input sentence: Run.
# Decoded sentence: Fuyez !
#
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# -
# Input sentence: Run.
# Decoded sentence: Fuyez !
#
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# -
# Input sentence: Run.
# Decoded sentence: Fuyez !
#
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# -
# Input sentence: Run.
# Decoded sentence: Fuyez !
